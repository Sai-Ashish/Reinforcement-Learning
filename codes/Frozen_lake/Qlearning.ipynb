# %%
import numpy as np
import gym
import random

env = gym.make("FrozenLake-v0")

action_size = env.action_space.n
state_size = env.observation_space.n

# %%
# Feel free to play with these hyperparameters

total_episodes =15000       # Total episodes
test_episodes = 100            # Test episodes
learning_rate = 0.8           # Learning rate
max_steps =  99              # Max steps per episode
gamma = 0.95                  # Discounting rate

# Exploration parameters
epsilon = 1.0                 # Exploration rate
max_epsilon = 1.0             # Exploration probability at start
min_epsilon = 0.01            # Minimum exploration probability 
decay_rate = 0.005            # Exponential decay rate for exploration prob

# %%
# Initializations
qtable = np.zeros((state_size, action_size))
rewards = []
print(qtable.shape)
# Out:
# (16, 4)

# %%
for episode in range(total_episodes):
    state = env.reset()
    step = 0
    done = False
    total_rewards = 0
    
    for step in range(max_steps):
        # Choose an action a in the current state (greedy or explore)
        
        # im doing an ephsilon greedy approach
        exp_exp_tradeoff = random.uniform(0, 1)  
        # exploitation (taking the max Q value for this state)
        if exp_exp_tradeoff > epsilon:
            # Enter code here            
            action = np.argmax(qtable[state,:])
            ## Hint: Greedily choose an action according to Q value

        # exploration
        else:
            # Enter code here
            ## Hint: Randomly choose an action
            action = env.action_space.sample()

        # Take this action and observe
        new_state, reward, done, info = env.step(action)

        # Do a Q update
        # Enter code here
        ## Hint: One line update equation convert to one line code, start with "qtable[state, action] = ..."
        qtable[state, action] = qtable[state, action] + learning_rate * (reward + gamma * np.max(qtable[new_state, :]) - qtable[state, action])
        
        total_rewards += reward
        
        state = new_state
        
        if done == True: 
            break
        
    # Decay epsilon to reduce exploration as time progresses
    
    # Enter code here to assign a decay value to "decay_parameter"
    decay_parameter = np.exp(-decay_rate*episode) 
    ## Hint: 
    ## 1. Use inbuilt polynomial, exponential(, or whatever works) functions to decay epsilon
    ## 2. "decay_parameter" is a function of "decay_rate" and "episode"
    
    epsilon = min_epsilon + (max_epsilon - min_epsilon)*decay_parameter
    rewards.append(total_rewards)

print("Score over time: " +  str(sum(rewards)/total_episodes))
print("Q values:")
print(qtable)
# Out:
# Score over time: 0.502472
# Q values:
# [[1.06604298e-01 4.89020646e-02 5.55658405e-02 5.58627083e-02]
#  [2.09496623e-03 1.14031622e-02 2.36897292e-03 5.93783756e-02]
#  [1.30710210e-02 3.70789941e-02 6.51422851e-03 4.77493593e-02]
#  [1.56839142e-03 1.31989524e-04 5.77272835e-03 4.81765689e-02]
#  [1.34294955e-01 6.35527315e-02 2.43045749e-02 1.15439294e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.03897266e-02 1.88843178e-04 3.96642155e-04 1.97306470e-10]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [8.42794618e-02 6.16658466e-04 3.55420027e-02 1.08463071e-01]
#  [6.35401759e-02 6.37215638e-01 1.39548430e-04 3.07810675e-02]
#  [8.80740883e-01 5.59787774e-04 2.08826465e-05 6.66272511e-04]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.74881122e-03 2.72472618e-02 5.63705035e-01 9.63693070e-02]
#  [5.93899253e-02 9.95351349e-01 7.39775169e-01 7.92416160e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]]

# %%
########################################################################
#################### Final policy animation ############################
########################################################################

print("We only print the last state in each episode, to see if our agent has reached the destination or fallen into a hole")
env.reset()
# Total episodes
test_episodes = 100      
for episode in range(test_episodes):
    state = env.reset()
    step = 0
    done = False
    print("****************************************************")
    print("EPISODE ", episode)

    for step in range(max_steps):
        # Taking action with Q learning
        action = np.argmax(qtable[state,:])
        
        new_state, reward, done, info = env.step(action)
        
        if done:
            env.render()
            
            print("Number of steps", step)
            break
        state = new_state
env.close()
# Out:
# We only print the last state in each episode, to see if our agent has reached the destination or fallen into a hole
# ****************************************************
# ('EPISODE ', 0)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 69)
# ****************************************************
# ('EPISODE ', 1)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 27)
# ****************************************************
# ('EPISODE ', 2)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 54)
# ****************************************************
# ('EPISODE ', 3)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 12)
# ****************************************************
# ('EPISODE ', 4)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 77)
# ****************************************************
# ('EPISODE ', 5)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 45)
# ****************************************************
# ('EPISODE ', 6)
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 7)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 9)
# ****************************************************
# ('EPISODE ', 8)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 9)
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 10)
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 11)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 49)
# ****************************************************
# ('EPISODE ', 12)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 69)
# ****************************************************
# ('EPISODE ', 13)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 38)
# ****************************************************
# ('EPISODE ', 14)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 81)
# ****************************************************
# ('EPISODE ', 15)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 49)
# ****************************************************
# ('EPISODE ', 16)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 75)
# ****************************************************
# ('EPISODE ', 17)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 17)
# ****************************************************
# ('EPISODE ', 18)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 45)
# ****************************************************
# ('EPISODE ', 19)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 9)
# ****************************************************
# ('EPISODE ', 20)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 31)
# ****************************************************
# ('EPISODE ', 21)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 23)
# ****************************************************
# ('EPISODE ', 22)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 25)
# ****************************************************
# ('EPISODE ', 23)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 22)
# ****************************************************
# ('EPISODE ', 24)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 24)
# ****************************************************
# ('EPISODE ', 25)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 69)
# ****************************************************
# ('EPISODE ', 26)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 44)
# ****************************************************
# ('EPISODE ', 27)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 10)
# ****************************************************
# ('EPISODE ', 28)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 16)
# ****************************************************
# ('EPISODE ', 29)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 44)
# ****************************************************
# ('EPISODE ', 30)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 21)
# ****************************************************
# ('EPISODE ', 31)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 29)
# ****************************************************
# ('EPISODE ', 32)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 70)
# ****************************************************
# ('EPISODE ', 33)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 34)
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 35)
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 36)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 26)
# ****************************************************
# ('EPISODE ', 37)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 20)
# ****************************************************
# ('EPISODE ', 38)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 9)
# ****************************************************
# ('EPISODE ', 39)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 22)
# ****************************************************
# ('EPISODE ', 40)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 68)
# ****************************************************
# ('EPISODE ', 41)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 42)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 43)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 70)
# ****************************************************
# ('EPISODE ', 44)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 9)
# ****************************************************
# ('EPISODE ', 45)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 12)
# ****************************************************
# ('EPISODE ', 46)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 23)
# ****************************************************
# ('EPISODE ', 47)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 48)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 49)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 23)
# ****************************************************
# ('EPISODE ', 50)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 89)
# ****************************************************
# ('EPISODE ', 51)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 25)
# ****************************************************
# ('EPISODE ', 52)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 53)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 62)
# ****************************************************
# ('EPISODE ', 54)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 13)
# ****************************************************
# ('EPISODE ', 55)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 19)
# ****************************************************
# ('EPISODE ', 56)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 57)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 18)
# ****************************************************
# ('EPISODE ', 58)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 71)
# ****************************************************
# ('EPISODE ', 59)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 12)
# ****************************************************
# ('EPISODE ', 60)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 21)
# ****************************************************
# ('EPISODE ', 61)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 35)
# ****************************************************
# ('EPISODE ', 62)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 75)
# ****************************************************
# ('EPISODE ', 63)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 36)
# ****************************************************
# ('EPISODE ', 64)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 46)
# ****************************************************
# ('EPISODE ', 65)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 66)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 8)
# ****************************************************
# ('EPISODE ', 67)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 61)
# ****************************************************
# ('EPISODE ', 68)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 69)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 11)
# ****************************************************
# ('EPISODE ', 70)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 14)
# ****************************************************
# ('EPISODE ', 71)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 31)
# ****************************************************
# ('EPISODE ', 72)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 14)
# ****************************************************
# ('EPISODE ', 73)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 72)
# ****************************************************
# ('EPISODE ', 74)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 75)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 28)
# ****************************************************
# ('EPISODE ', 76)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 8)
# ****************************************************
# ('EPISODE ', 77)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 70)
# ****************************************************
# ('EPISODE ', 78)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 26)
# ****************************************************
# ('EPISODE ', 79)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 80)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 15)
# ****************************************************
# ('EPISODE ', 81)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 19)
# ****************************************************
# ('EPISODE ', 82)
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 83)
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 84)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 20)
# ****************************************************
# ('EPISODE ', 85)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 24)
# ****************************************************
# ('EPISODE ', 86)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 6)
# ****************************************************
# ('EPISODE ', 87)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 16)
# ****************************************************
# ('EPISODE ', 88)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 74)
# ****************************************************
# ('EPISODE ', 89)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 39)
# ****************************************************
# ('EPISODE ', 90)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 99)
# ****************************************************
# ('EPISODE ', 91)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 79)
# ****************************************************
# ('EPISODE ', 92)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 25)
# ****************************************************
# ('EPISODE ', 93)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 24)
# ****************************************************
# ('EPISODE ', 94)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 62)
# ****************************************************
# ('EPISODE ', 95)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 44)
# ****************************************************
# ('EPISODE ', 96)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 88)
# ****************************************************
# ('EPISODE ', 97)
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 16)
# ****************************************************
# ('EPISODE ', 98)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 24)
# ****************************************************
# ('EPISODE ', 99)
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# ('Number of steps', 46)
