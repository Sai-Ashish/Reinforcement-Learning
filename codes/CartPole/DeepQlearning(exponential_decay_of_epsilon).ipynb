# %%
#help taken from anirudh topiwala git-repo

import random
import gym
import math
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
def preprocess_state(state):
    return np.reshape(state, [1, 4])

def replay(model,gamma,memory, batch_size):
    
    x_batch, y_batch = [], []
    #sample a random mini batch out of the memory stored in previous episode
    minibatch = random.sample(memory, min(len(memory), batch_size))
    for state, action, reward, next_state, done in minibatch:
        y_target = model.predict(state)
        y_target[0][action] = reward if done else reward + gamma * np.max(model.predict(next_state)[0])
        x_batch.append(state[0])
        y_batch.append(y_target[0])

    model.fit(np.array(x_batch), np.array(y_batch), batch_size=len(x_batch), verbose=0)

# %%
#  all the parameters needed
n_episodes=30000
n_win_ticks=500
# can have any number of steps per episode thus none
max_env_steps=None
gamma=0.99
epsilon=1.0 
epsilon_min=0.01
epsilon_decay=0.1
epsilon_max = 1.0
alpha=0.01
alpha_decay=0.01 
batch_size=64 
monitor=False 
quiet=False

# Model
model = Sequential()
model.add(Dense(24, input_dim=4, activation='relu'))
model.add(Dense(48, activation='relu'))
model.add(Dense(2, activation='linear'))
model.compile(loss='mse', optimizer=Adam(lr=alpha, decay=alpha_decay))


# environment setting 
memory = deque(maxlen=100000)
env = gym.make('CartPole-v1')
if monitor: self.env = gym.wrappers.Monitor(self.env, '../data/cartpole-1', force=True)

scores = deque(maxlen=100)
solved = 0

# %%
for e in range(n_episodes):
    state = preprocess_state(env.reset())
    done = False
    i = 0
    #run completely for one complete game for instance 
    #assuming some model for q given state and action initially the the model updates each time it runs
    while not done:
#         env.render()
        
        #for exploration
#         eps = max(epsilon_min, min(epsilon, 1.0 - math.log10((e + 1) * epsilon_decay)))
        eps = epsilon
#         print(eps)
        action = env.action_space.sample() if (np.random.random() <= eps) else np.argmax(model.predict(state))
        
        #Next state prediction
        next_state, reward, done, _ = env.step(action)
        next_state = preprocess_state(next_state)
        memory.append((state, action, reward, next_state, done)) 
        state = next_state
        i += 1

    # score basically it the number of steps per episode it has survived thus has been assigned to i which is 
    # incremented every time step it is not done

    scores.append(i)
    mean_score = np.mean(scores)
    if mean_score >= n_win_ticks and e >= 100:
        if not quiet: print('Ran {} episodes. Solved after {} trials ✔'.format(e, e - 100))
        solved = 1
        break
            
    if e % 100 == 0 and not quiet:
        print('[Episode {}] - Mean survival time over last 100 episodes was {} streaks.'.format(e, mean_score))

    replay(model,gamma,memory,batch_size)
    
    #reduce the epsilon over episode so that we reduce the exploration and increase exploitation over time 
    if epsilon > epsilon_min:
#             epsilon *= epsilon_decay
        epsilon = epsilon_min + (epsilon_max - epsilon_min)*np.exp(-epsilon_decay*e)

if not quiet and solved == 0: print('Did not solve after {} episodes'.format(e))
# env.close()
# Out:
# [Episode 0] - Mean survival time over last 100 episodes was 23.0 streaks.
# [Episode 100] - Mean survival time over last 100 episodes was 24.92 streaks.
# [Episode 200] - Mean survival time over last 100 episodes was 29.15 streaks.
# [Episode 300] - Mean survival time over last 100 episodes was 36.22 streaks.
# [Episode 400] - Mean survival time over last 100 episodes was 44.43 streaks.
# [Episode 500] - Mean survival time over last 100 episodes was 58.25 streaks.
# [Episode 600] - Mean survival time over last 100 episodes was 61.6 streaks.
# [Episode 700] - Mean survival time over last 100 episodes was 75.18 streaks.
# [Episode 800] - Mean survival time over last 100 episodes was 103.28 streaks.
# [Episode 900] - Mean survival time over last 100 episodes was 103.03 streaks.
# [Episode 1000] - Mean survival time over last 100 episodes was 149.23 streaks.
# [Episode 1100] - Mean survival time over last 100 episodes was 150.0 streaks.
# [Episode 1200] - Mean survival time over last 100 episodes was 361.15 streaks.
# [Episode 1300] - Mean survival time over last 100 episodes was 346.44 streaks.
# [Episode 1400] - Mean survival time over last 100 episodes was 178.0 streaks.
# [Episode 1500] - Mean survival time over last 100 episodes was 143.37 streaks.
# [Episode 1600] - Mean survival time over last 100 episodes was 66.15 streaks.
# [Episode 1700] - Mean survival time over last 100 episodes was 40.64 streaks.
# [Episode 1800] - Mean survival time over last 100 episodes was 49.21 streaks.
# [Episode 1900] - Mean survival time over last 100 episodes was 403.67 streaks.
# [Episode 2000] - Mean survival time over last 100 episodes was 123.15 streaks.
# [Episode 2100] - Mean survival time over last 100 episodes was 12.96 streaks.
# [Episode 2200] - Mean survival time over last 100 episodes was 9.59 streaks.
# [Episode 2300] - Mean survival time over last 100 episodes was 9.99 streaks.
# [Episode 2400] - Mean survival time over last 100 episodes was 296.22 streaks.
# [Episode 2500] - Mean survival time over last 100 episodes was 336.27 streaks.
# [Episode 2600] - Mean survival time over last 100 episodes was 161.13 streaks.
# [Episode 2700] - Mean survival time over last 100 episodes was 131.68 streaks.
# [Episode 2800] - Mean survival time over last 100 episodes was 58.59 streaks.
# [Episode 2900] - Mean survival time over last 100 episodes was 16.32 streaks.
# [Episode 3000] - Mean survival time over last 100 episodes was 14.8 streaks.
# [Episode 3100] - Mean survival time over last 100 episodes was 17.01 streaks.
# [Episode 3200] - Mean survival time over last 100 episodes was 17.22 streaks.
# [Episode 3300] - Mean survival time over last 100 episodes was 74.63 streaks.
# [Episode 3400] - Mean survival time over last 100 episodes was 117.28 streaks.
# [Episode 3500] - Mean survival time over last 100 episodes was 142.31 streaks.
# [Episode 3600] - Mean survival time over last 100 episodes was 179.56 streaks.
# [Episode 3700] - Mean survival time over last 100 episodes was 199.11 streaks.
# [Episode 3800] - Mean survival time over last 100 episodes was 242.95 streaks.
# [Episode 3900] - Mean survival time over last 100 episodes was 403.58 streaks.
# [Episode 4000] - Mean survival time over last 100 episodes was 498.31 streaks.
# [Episode 4100] - Mean survival time over last 100 episodes was 499.13 streaks.
# [Episode 4200] - Mean survival time over last 100 episodes was 499.57 streaks.
# Ran 4219 episodes. Solved after 4119 trials ✔

# %%
# render the model  
time = []
for i_episode in range(1000):
    observation = env.reset()
    for t in range(1000):
        env.render()
        state = preprocess_state(observation)
        action = np.argmax(model.predict(state)[0])
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            time.append((t+1))
            break
print(np.mean(time))
env.close()
# Out:
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# Episode finished after 500 timesteps
# 500.0

# %%
print time
# Out:
# [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, ...
